# %%
# if first time, make sure pip install wordcloud
# !pip install wordcloud
# Out:
# ...
#   Created wheel for wordcloud: filename=wordcloud-1.8.1-cp39-cp39-win_amd64.whl size=152209 sha256=72ffa8ca2af0f025680c0e59814f1cc5d0c77deb4b823d1a537c8ce22127e2d9
#   Stored in directory: c:\users\ouyan\appdata\local\pip\cache\wheels\f9\7a\dd\06ef8b5dfe5483f6204133c08eeb16c287cc2c05e290ae2fc0
# Successfully built wordcloud
# ...
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\ouyan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\ouyan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\ouyan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\ouyan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\ouyan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\ouyan\anaconda3\lib\site-packages)
# ...

# %%
from urllib.request import urlopen
from xml.etree.ElementTree import parse
import pandas as pd


from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
var_url = urlopen('https://moxie.foxnews.com/feedburner/politics.xml')
xmldoc = parse(var_url)

# %%
titleall=[]
for item in xmldoc.iterfind('channel/item'):
    title = item.findtext('title')
    titleall.append(title)

# %%
titleall=" ".join(titleall)

# %%
# Create a list of word
text=("Python Python Python Matplotlib")

# Create the wordcloud object
wordcloud = WordCloud().generate(titleall)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
